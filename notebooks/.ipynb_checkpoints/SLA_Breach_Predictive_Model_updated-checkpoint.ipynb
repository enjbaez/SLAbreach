# %% [markdown]
# # Predictive SLA‑Breach Model
# This notebook demonstrates an **end‑to‑end workflow** to explore, feature‑engineer and train a model that predicts whether a pharmacy benefit change‑request will breach the 5‑day service‑level agreement (SLA).
#
# **Dataset:** synthetic 500‑row sample generated for prototyping (`dummy_change_request_data.csv`).
#
# **Pipeline outline:**
# 1. Load & validate data
# 2. Exploratory Data Analysis (EDA)
# 3. Feature Engineering
# 4. Train/Test split
# 5. Model training (Logistic Regression + Gradient Boosting)
# 6. Evaluation & interpretation
# 7. Save model artifact
#
# *Feel free to run each cell sequentially or adapt the code for your production environment.*

# %%
import os; print(os.getcwd())
# Out:
# C:\Users\enjol\OneDrive\Desktop\Medical Economics\SLAbreach\notebooks

# %%
import sys, sklearn, numpy
print("Python:", sys.executable)
print("sklearn:", sklearn.__version__)
print("numpy:", numpy.__version__)
# Out:
# Python: C:\Users\enjol\anaconda3\python.exe
# sklearn: 1.5.1
# numpy: 1.26.4

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\enjol\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy in c:\users\enjol\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\enjol\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\enjol\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (3.9.2)
# Requirement already satisfied: seaborn in c:\users\enjol\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: joblib in c:\users\enjol\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: jupyter in c:\users\enjol\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\enjol\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\enjol\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\enjol\anaconda3\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\enjol\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\enjol\anaconda3\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\enjol\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\enjol\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\enjol\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\enjol\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\enjol\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\enjol\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\enjol\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: notebook in c:\users\enjol\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 7)) (7.2.2)
# Requirement already satisfied: qtconsole in c:\users\enjol\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 7)) (5.7.0)
# Requirement already satisfied: jupyter-console in c:\users\enjol\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 7)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\enjol\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 7)) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\enjol\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 7)) (6.31.0)
# Requirement already satisfied: ipywidgets in c:\users\enjol\anaconda3\lib\site-packages (from jupyter->-r requirements.txt (line 7)) (7.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\enjol\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (8.27.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (0.1.6)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (5.9.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\enjol\anaconda3\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\enjol\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\enjol\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 7)) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\enjol\anaconda3\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 7)) (3.0.43)
# Requirement already satisfied: pygments in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 7)) (2.15.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\enjol\anaconda3\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 7)) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\enjol\anaconda3\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 7)) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\enjol\anaconda3\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 7)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\enjol\anaconda3\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 7)) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\enjol\anaconda3\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: ipython_pygments_lexers in c:\users\enjol\anaconda3\lib\site-packages (from qtconsole->jupyter->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\enjol\anaconda3\lib\site-packages (from qtconsole->jupyter->-r requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\enjol\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: decorator in c:\users\enjol\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\enjol\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\enjol\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: colorama in c:\users\enjol\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 7)) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 7)) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 7)) (80.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\enjol\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\enjol\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 7)) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\enjol\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 7)) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\enjol\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: idna>=2.8 in c:\users\enjol\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\enjol\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\enjol\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (21.2.0)
# Requirement already satisfied: certifi in c:\users\enjol\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 7)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\enjol\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 7)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\enjol\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->-r requirements.txt (line 7)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\enjol\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\enjol\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\enjol\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\enjol\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter->-r requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: executing in c:\users\enjol\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\enjol\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\enjol\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (2.1)
# Requirement already satisfied: uri-template in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\enjol\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\enjol\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\enjol\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\enjol\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->-r requirements.txt (line 7)) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# For modeling
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score, RocCurveDisplay
)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
import pickle
import joblib  # for saving model

# Load data
csv_file = "../data/dummy_change_request_data.csv"

# %%
df = pd.read_csv(csv_file)

# %%
# Parse dates
date_cols = [
    "cr date created", "cr date closed",
    "test results received date", "test results approved date"
]
for col in date_cols:
    df[col] = pd.to_datetime(df[col], format="%Y%m%d")

df.head()
# Out:
#        plan  RxCaseID cr date created cr date closed             category  \
# 0  dumplan1    229756      2024-04-21     2025-07-04  Step Therapy Update
# 1  dumplan2    688526      2024-03-26     2024-05-24   Coverage Expansion
# 2  dumplan3    762717      2023-06-07     2023-06-30        Formulary Add
# 3  dumplan4    616460      2021-08-30     2023-06-22          Tier Change
# 4  dumplan5    699092      2021-10-19     2023-09-24        Formulary Add
#
#    TestingCaseID test results received date test results approved date  \
# 0        4044044                 2024-10-05                 2025-05-19
# 1        3034850                 2024-05-02                 2024-05-12
# 2        5791196                 2023-06-24                 2023-06-28
# 3        2874322                 2023-06-22                 2023-06-22
# 4        9725832                 2022-02-20                 2023-01-03
#
#          comments
# 0  High cost drug
# 1             NaN
# 2  High cost drug
# 3             NaN
# 4             NaN

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %%
print("Dataset shape:", df.shape)
print("\nData types:")
print(df.dtypes)

# Missing values
print("\nMissing values per column:")
print(df.isna().sum())

# SLA durations
df['request_SLA_days'] = (df['cr date closed'] - df['cr date created']).dt.days
df['testing_SLA_days'] = (df['test results approved date'] - df['test results received date']).dt.days

# Cap extreme open requests at < 365 days
# Business assumption: in real operations, a request should not stay open more than one year.
df = df[df['request_SLA_days'] < 365]

fig, ax = plt.subplots()
df['request_SLA_days'].hist(ax=ax)
ax.set_title("Distribution of Request SLA (days)")
ax.set_xlabel("Days")
ax.set_ylabel("Frequency")
plt.show()
# Out:
# Dataset shape: (500, 9)
#
# Data types:
# plan                                  object
# RxCaseID                               int64
# cr date created               datetime64[ns]
# cr date closed                datetime64[ns]
# category                              object
# TestingCaseID                          int64
# test results received date    datetime64[ns]
# test results approved date    datetime64[ns]
# comments                              object
# dtype: object
#
# Missing values per column:
# plan                            0
# RxCaseID                        0
# cr date created                 0
# cr date closed                  0
# category                        0
# TestingCaseID                   0
# test results received date      0
# test results approved date      0
# comments                      244
# dtype: int64

# %% [markdown]
# ## 2. Feature Engineering

# %%
# Binary target: breach if request_SLA_days > 5
SLA_THRESHOLD = 5
df['breach'] = (df['request_SLA_days'] > SLA_THRESHOLD).astype(int)

# Base features
df['month'] = df['cr date created'].dt.month
df['year'] = df['cr date created'].dt.year

feature_cols = [
    'request_SLA_days', 'testing_SLA_days', 'month', 'year', 'category'
]

X = df[feature_cols]
y = df['breach']

# Categorical cols
cat_features = ['category']
num_features = ['request_SLA_days', 'testing_SLA_days', 'month', 'year']

# Preprocess: one‑hot encode category
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features),
        ('num', 'passthrough', num_features)
    ]
)

# %% [markdown]
# ## 3. Train/Test Split & Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# Logistic Regression pipeline
logreg_pipeline = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('model', LogisticRegression(max_iter=1000))
])

# Gradient Boosting pipeline
gb_pipeline = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('model', GradientBoostingClassifier())
])

models = {
    'LogisticRegression': logreg_pipeline,
    'GradientBoosting': gb_pipeline
}

for name, pipe in models.items():
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    y_proba = pipe.predict_proba(X_test)[:, 1]
    auc = roc_auc_score(y_test, y_proba)
    print(f"\n=== {name} ===")
    print("AUC:", round(auc, 3))
    print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# === LogisticRegression ===
# AUC: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00       145
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# weighted avg       1.00      1.00      1.00       150
#
#
# === GradientBoosting ===
# AUC: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      1.00      1.00       145
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# weighted avg       1.00      1.00      1.00       150

# %% [markdown]
# ## 4. Evaluation: ROC Curve

# %%
best_model = gb_pipeline  # choose based on AUC above
RocCurveDisplay.from_estimator(best_model, X_test, y_test)
plt.show()

# %% [markdown]
# ## 5. Save Model Artifact

# %%
model_path = "../models/gb_sla_breach_model.pkl"
joblib.dump(best_model, model_path)
print("Model saved to:", model_path)
# Out:
# Model saved to: ../models/gb_sla_breach_model.pkl

# %%
# Replace 'your_file.pkl' with the actual path to your PKL file
#file_path = 'your_file.pkl'

# Open the file in binary read mode ('rb') and load the data
with open(model_path, 'rb') as file:
    data = pickle.load(file)

# 'data' now contains the deserialized Python object
print(data)
# Out:
# ['request_SLA_days' 'testing_SLA_days' 'month' 'year' 'category']

# %% [markdown]
# ### 6. Next Steps
# * Integrate with live SharePoint data via Power Automate.
# * Schedule daily inference job and write predictions back to a risk‑monitoring list.
# * Enhance feature set with rolling backlog metrics and requester metadata.
# * Perform hyper‑parameter tuning (e.g., `GridSearchCV`) for production deployment.
